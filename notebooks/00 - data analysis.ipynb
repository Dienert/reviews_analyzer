# %%
import pandas as pd

# %%
df = pd.read_csv('Outliers-Story-Success-Malcolm-Gladwell.csv')
df
# Out:
#                reviewer stars  \
# 0         Pedro Pimenta     5
# 1                 Fabio     5
# 2     Roger H. Da Silva     5
# 3       Helio Brilhante     4
# 4                Flavia     4
# ...                 ...   ...
# 7728           VIPGroup     5
# 7729           pagr228      5
# 7730             Jordan     5
# 7731      Kurt A. David     5
# 7732       Ariel Berman     5
#
#                                                   title  \
# 0                              Um literal "abre-mentes"
# 1                                                 Ótimo
# 2                             Esclarecedor e motivador!
# 3                                       Excelente livro
# 4     Para quem quer entender mais sobre sucesso pro...
# ...                                                 ...
# 7728                                         Five Stars
# 7729                                            So good
# 7730                                         Five Stars
# ...

# %%
df['country'] = df.date.apply(lambda text: ' '.join(text.split(" em ")[0].split(" ")[2:]))

# %%
df
# Out:
#                reviewer stars  \
# 0         Pedro Pimenta     5
# 1                 Fabio     5
# 2     Roger H. Da Silva     5
# 3       Helio Brilhante     4
# 4                Flavia     4
# ...                 ...   ...
# 7728           VIPGroup     5
# 7729           pagr228      5
# 7730             Jordan     5
# 7731      Kurt A. David     5
# 7732       Ariel Berman     5
#
#                                                   title  \
# 0                              Um literal "abre-mentes"
# 1                                                 Ótimo
# 2                             Esclarecedor e motivador!
# 3                                       Excelente livro
# 4     Para quem quer entender mais sobre sucesso pro...
# ...                                                 ...
# 7728                                         Five Stars
# 7729                                            So good
# 7730                                         Five Stars
# ...

# %%
df.country.value_counts()
# Out:
# Estados Unidos    5289
# Reino Unido        823
# Índia              744
# Canadá             300
# Alemanha           182
# México             130
# França              58
# Austrália           54
# Espanha             52
# Itália              38
# Japão               32
# Brasil              24
# Holanda              4
# Polônia              2
#                      1
# Name: country, dtype: int64

# %%
df.stars.value_counts()
# Out:
# 5        5468
# 4        1468
# 3         457
# 1         176
# 2         163
# stars       1
# Name: stars, dtype: int64
