# %%
import pandas as pd
from datetime import datetime
import locale 
print("locale", "=>", locale.setlocale(locale.LC_ALL, "en.UTF-8"))
# Out:
# locale => en.UTF-8

# %%
df_flipkart = pd.read_csv('../dataset/raw/barnesandnoble.csv')
df_flipkart
# Out:
#             reviewer  stars                                   title  \
# 0          reader347      1                       Not my cup of tea
# 1                NaN      5                       Sensational Book!
# 2         txpenelope      3  Good but not like Talking To Strangers
# 3     OutTheBackdoor      5                              Insightful
# 4                NaN      3                                     NaN
# ...              ...    ...                                     ...
# 1280             NaN      5                                     NaN
# 1281             NaN      5                                     NaN
# 1282             NaN      2                                     NaN
# 1283             NaN      3                                     NaN
# 1284          csaint      3                     Outliers, a success
#
#                                                  review  \
# 0     If you are looking for a page turner, this is ...
# 1     The world fosters competition at an exponentia...
# 2     This was a very interesting audiobook. Gladwel...
# 3     Insightful, a book anyone can take a lesson or...
# 4                                                   NaN
# ...                                                 ...
# 1280                                                NaN
# 1281                                                NaN
# 1282                                                NaN
# 1283                                                NaN
# 1284  This was a great insight into the world of suc...
#
#                                date
# 0     2021-09-06T20:45:45.000+00:00
# 1     2021-05-17T12:21:22.000+00:00
# 2     2021-04-02T15:48:44.000+00:00
# 3     2020-12-28T01:14:00.000+00:00
# 4     2019-01-14T19:22:01.000+00:00
# ...                             ...
# 1280  2008-11-17T16:06:14.000+00:00
# 1281  2008-11-16T16:14:31.000+00:00
# 1282  2008-11-11T04:24:30.000+00:00
# 1283  2008-11-07T21:18:17.000+00:00
# 1284  2008-10-30T18:28:35.000+00:00
#
# [1285 rows x 5 columns]

# %%
df_flipkart['date'] = df_flipkart.date.str[:10]

# joining title and review into review
df_flipkart['review'] = df_flipkart.title + ". " + df_flipkart.review

# %%
df_flipkart
# Out:
#             reviewer  stars                                   title  \
# 0          reader347      1                       Not my cup of tea
# 1                NaN      5                       Sensational Book!
# 2         txpenelope      3  Good but not like Talking To Strangers
# 3     OutTheBackdoor      5                              Insightful
# 4                NaN      3                                     NaN
# ...              ...    ...                                     ...
# 1280             NaN      5                                     NaN
# 1281             NaN      5                                     NaN
# 1282             NaN      2                                     NaN
# 1283             NaN      3                                     NaN
# 1284          csaint      3                     Outliers, a success
#
#                                                  review        date
# 0     Not my cup of tea. If you are looking for a pa...  2021-09-06
# 1     Sensational Book!. The world fosters competiti...  2021-05-17
# 2     Good but not like Talking To Strangers. This w...  2021-04-02
# 3     Insightful. Insightful, a book anyone can take...  2020-12-28
# 4                                                   NaN  2019-01-14
# ...                                                 ...         ...
# 1280                                                NaN  2008-11-17
# 1281                                                NaN  2008-11-16
# 1282                                                NaN  2008-11-11
# 1283                                                NaN  2008-11-07
# 1284  Outliers, a success. This was a great insight ...  2008-10-30
#
# [1285 rows x 5 columns]
