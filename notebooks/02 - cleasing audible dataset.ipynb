# %%
import pandas as pd
from datetime import datetime
import locale 
print("locale", "=>", locale.setlocale(locale.LC_ALL, "en.UTF-8"))
# Out:
# locale => en.UTF-8

# %%
df_flipkart = pd.read_csv('../dataset/raw/audible.csv')
df_flipkart
# Out:
#             reviewer stars                                       title  \
# 0       Gaggleframpf     1                  Not Really About Outliers.
# 1        Leah C. Day     3                                 Interesting
# 2         GW Support     1  Don’t dilute your potential with this book
# 3     Scott T. Hards     3                     Engaging, but overrated
# 4             KevinH     5             Captivating (if not an outlier)
# ...              ...   ...                                         ...
# 2111         Roxanne     5                     Gladwell reads Gladwell
# 2112            Seda     2                                 boring book
# 2113           Aaron     5              What can I say? It's Gladwell.
# 2114            Judy     o                              liked it a lot
# 2115  Richard Decker     5                             His best by far
#
#                                                  review      date
# 0     This books title leads you to believe that it'...  09-30-19
# 1     This was a pretty interesting book. I don't ag...  09-14-09
# 2     This book’s entire theme is basically that cha...  02-15-19
# 3     Outliers has many interesting statistical anec...  12-13-08
# 4     Regardless of what you ultimately think of the...  11-21-08
# ...                                                 ...       ...
# 2111  Malcolm Gladwell has a wonderful voice, as wel...  02-07-09
# 2112  I felt like he could say what he wanted to say...  02-02-09
# 2113                                                NaN  12-26-12
# 2114                                       great reader  04-12-09
# 2115  This is by far Gladwell's best book.  A must l...  12-10-08
#
# [2116 rows x 5 columns]

# %%
# joining title and review into review
df_flipkart['review'] = df_flipkart.title + ". " + df_flipkart.review

# %%
df_flipkart
# Out:
#             reviewer stars                                       title  \
# 0       Gaggleframpf     1                  Not Really About Outliers.
# 1        Leah C. Day     3                                 Interesting
# 2         GW Support     1  Don’t dilute your potential with this book
# 3     Scott T. Hards     3                     Engaging, but overrated
# 4             KevinH     5             Captivating (if not an outlier)
# ...              ...   ...                                         ...
# 2111         Roxanne     5                     Gladwell reads Gladwell
# 2112            Seda     2                                 boring book
# 2113           Aaron     5              What can I say? It's Gladwell.
# 2114            Judy     o                              liked it a lot
# 2115  Richard Decker     5                             His best by far
#
#                                                  review      date
# 0     Not Really About Outliers.. This books title l...  09-30-19
# 1     Interesting. This was a pretty interesting boo...  09-14-09
# 2     Don’t dilute your potential with this book. Th...  02-15-19
# 3     Engaging, but overrated. Outliers has many int...  12-13-08
# 4     Captivating (if not an outlier). Regardless of...  11-21-08
# ...                                                 ...       ...
# 2111  Gladwell reads Gladwell. Malcolm Gladwell has ...  02-07-09
# 2112  boring book. I felt like he could say what he ...  02-02-09
# 2113                                                NaN  12-26-12
# 2114                       liked it a lot. great reader  04-12-09
# 2115  His best by far. This is by far Gladwell's bes...  12-10-08
#
# [2116 rows x 5 columns]
